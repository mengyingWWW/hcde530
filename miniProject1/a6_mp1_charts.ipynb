# %% [markdown]
# # A6 — MP1 charts (Plotly → PNG)
#
# This notebook installs export dependencies, then runs `a6_mp1_charts.py` to regenerate the static images in `charts/`.
#
# **Tip:** Run from the repo root (`hcde530/`) so the path to `miniProject1/` resolves correctly.

# %%
# %pip install -q plotly kaleido pandas

# %%
import runpy
from pathlib import Path

here = Path.cwd().resolve()
script = here / "miniProject1" / "a6_mp1_charts.py"
if not script.exists():
    script = here / "a6_mp1_charts.py"
if not script.exists():
    raise FileNotFoundError(f"Could not find a6_mp1_charts.py from {here}")

runpy.run_path(str(script), run_name="__main__")
print("Done. See miniProject1/charts/*.png")
